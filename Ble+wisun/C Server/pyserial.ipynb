# %%
import serial

# %%
ser  = serial.Serial(port = 'COM11', baudrate=9600)

# %%
#write a string to ser port and read it back
ser.write(b'wisun get wisun\n')
print(ser.readline().decode('utf-8'))
# Out:
# wisun.regulatory_domain = EU (3)
